# %% [markdown]
# conda install plotly
# pip install plotly

# %%
import pandas as pd
import plotly.express as pe

# %%
path = "https://raw.githubusercontent.com/techficent/oracle-predictive-analytics/main/Balanced_credit_Risk.csv"

df = pd.read_csv (path)

df
# Out:
#        index  person_age  person_income person_home_ownership  \
# 0          0          22          59000                  RENT
# 1          1          25           9600              MORTGAGE
# 2          2          23          65500                  RENT
# 3          3          24          54400                  RENT
# 4          4          21           9900                   OWN
# ...      ...         ...            ...                   ...
# 12401  12401          30         102540              MORTGAGE
# 12402  12402          24          60000                  RENT
# 12403  12403          22          40000                  RENT
# 12404  12404          22          50000                  RENT
# 12405  12405          24         108000                  RENT
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate loan_status
# 0             PERSONAL          D      35000          16.02         YES
# 1              MEDICAL          C       5500          12.87         YES
# ...

# %% [markdown]
# ## exploration

# %%
df.shape
# Out:
# (12406, 9)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12406, step=1)

# %%
df.columns
# Out:
# Index(['index', 'person_age', 'person_income', 'person_home_ownership',
#        'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate',
#        'loan_status'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# index                    0
# person_age               0
# person_income            0
# person_home_ownership    0
# loan_intent              0
# loan_grade               0
# loan_amnt                0
# loan_int_rate            0
# loan_status              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12406 entries, 0 to 12405
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  12406 non-null  int64
#  1   person_age             12406 non-null  int64
#  2   person_income          12406 non-null  int64
#  3   person_home_ownership  12406 non-null  object
#  4   loan_intent            12406 non-null  object
#  5   loan_grade             12406 non-null  object
#  6   loan_amnt              12406 non-null  int64
#  7   loan_int_rate          12406 non-null  float64
#  8   loan_status            12406 non-null  object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 872.4+ KB

# %%
df.nunique()
# Out:
# index                    12406
# person_age                  50
# person_income             2184
# person_home_ownership        4
# loan_intent                  6
# loan_grade                   7
# loan_amnt                  576
# loan_int_rate              340
# loan_status                  2
# dtype: int64

# %%
df.sample(1)
# Out:
#        index  person_age  person_income person_home_ownership  \
# 10489  10489          37          88296              MORTGAGE
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate loan_status
# 10489  HOMEIMPROVEMENT          B      15000          10.14          NO

# %%
categorical_columns = ['person_home_ownership','loan_intent',
'loan_grade', 'loan_status' ]

real_columns = ['person_age', 'person_income' , 'loan_amnt', 'loan_int_rate']

# %%
df [ categorical_columns ] = df[    categorical_columns   ].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12406 entries, 0 to 12405
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  12406 non-null  int64
#  1   person_age             12406 non-null  int64
#  2   person_income          12406 non-null  int64
#  3   person_home_ownership  12406 non-null  category
#  4   loan_intent            12406 non-null  category
#  5   loan_grade             12406 non-null  category
#  6   loan_amnt              12406 non-null  int64
#  7   loan_int_rate          12406 non-null  float64
#  8   loan_status            12406 non-null  category
# dtypes: category(4), float64(1), int64(4)
# memory usage: 534.1 KB

# %%
df[       real_columns           ].describe()
# Out:
#          person_age  person_income     loan_amnt  loan_int_rate
# count  12406.000000   1.240600e+04  12406.000000   12406.000000
# mean      27.594470   6.040450e+04  10187.790182      11.784964
# std        6.247178   4.454757e+04   6692.722063       3.391123
# min       20.000000   4.000000e+03    800.000000       5.420000
# 25%       23.000000   3.461550e+04   5000.000000       8.940000
# 50%       26.000000   5.091500e+04   8800.000000      11.830000
# 75%       30.000000   7.300000e+04  14000.000000      14.420000
# max      144.000000   1.362000e+06  35000.000000      23.220000

# %% [markdown]
# plotly & plotly express!
#
# bar
# histogram
# boxplots
# line charts

# %%
pe.box(    y="person_income",  data_frame=df      )

# %%
for col in real_columns:
    fig = pe.box(    y=col,  data_frame=df      )
    display(fig)

# %%
pe.box(     y=['loan_int_rate', 'person_age'],  data_frame=df       )

# %%
### correlation between 2 real-value columns

# %% [markdown]
# # x-axis
# # y-axis
# # color (categorical column/real-value)
# # facet_row (categorical)
# # facet_col  (categorical)

# %%
pe.scatter(    
    x='person_income',  
    y='loan_amnt', 
    data_frame=df, 
    color='person_age', 
    facet_row='loan_status',
    facet_col='person_home_ownership'
)

# %% [markdown]
# ### Average loan_amount for each category of loan_status

# %%
result = df.groupby(['loan_status']) [     ['loan_amnt']      ].mean()

display(result)

pe.bar(     y='loan_amnt', data_frame=result, color=result.index        )
# Out:
#                 loan_amnt
# loan_status
# NO            9352.228760
# YES          11023.351604

# %%
categorical_columns
# Out:
# ['person_home_ownership', 'loan_intent', 'loan_grade', 'loan_status']

# %%
pe.sunburst(      path=['loan_intent', 'loan_grade', 'loan_status'], data_frame=df                )

# %% [markdown]
# ### functions in Python

# %%
def exploration(  df  ):
    display(   df.columns  )
    display(   df.index    )
    display(  df.shape     )

# %%
exploration(df)
# Out:
# Index(['index', 'person_age', 'person_income', 'person_home_ownership',
#        'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate',
#        'loan_status'],
#       dtype='object')
# RangeIndex(start=0, stop=12406, step=1)
# (12406, 9)

# %%
path = "https://raw.githubusercontent.com/techficent/oracle-predictive-analytics/main/Loan_Status_Classification.csv"
loan_df = pd.read_csv(path)
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
# RangeIndex(start=0, stop=298, step=1)
# (298, 12)

# %%
exploration(loan_df)

# %%
def  addition (    n1 : int or float ,   n2 : int or float   ) -> None :
    #if n1 is either float or int AND n2 is also float or int:
    if(  isinstance(n1,  (int, float)  )  and  isinstance(n2, (int,float) ) ):
        print(f"The addition of {n1} and {n2} is {n1 + n2}")
    # else, print an error message
    else:
        print("incompatible types")

# %%
addition(10, 20)
addition(400, 20)
addition(100, 200)
addition("harshit", "shukla") #concatenated strings
addition([1,2,3], [2,60,70]) #new list by merging into one extended list
# Out:
# The addition of 10 and 20 is 30
# The addition of 400 and 20 is 420
# The addition of 100 and 200 is 300
# incompatible types
# incompatible types

# %% [markdown]
# ### lambda functions
#
#
# lambda     <input-variables>    :     <output-expression>

# %%
#ans is a list of mapping square function on each value of this list
ans = list ( map(   lambda  number :  number ** 2  ,   [1,2,3,4,5]  ) )  #apply function to each item in data collections
ans
# Out:
# [1, 4, 9, 16, 25]

# %%
ans = list ( map(   lambda  number :  number ** 3 ,   [1,2,3,4,5]  ) )  #apply function to each item in data collections
ans
# Out:
# [1, 8, 27, 64, 125]

# %%
ans = list ( map(   lambda  number :  0.9 * number ,   [1,2,3,4,5]  ) )  #apply function to each item in data collections
ans
# Out:
# [0.9, 1.8, 2.7, 3.6, 4.5]

# %%
import math

ans = list ( map(   math.factorial  ,   [1,2,3,4,5]  ) )  #apply function to each item in data collections
ans
# Out:
# [1, 2, 6, 24, 120]

# %%
ans = list ( map(   math.sqrt  ,   [1,2,3,4,5]  ) )  #apply function to each item in data collections
ans
# Out:
# [1.0, 1.4142135623730951, 1.7320508075688772, 2.0, 2.23606797749979]
